# %% [markdown]
# # Challenge 06: Image Classification Case
#
# Build a CNN to classify handwritten digits (MNIST).
# Focus on understanding convolution layers and feature maps.

# %%
# Setup
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\Steven Barr\workspace\my-ai-project\.venv\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:73
#      72 try:
# ---> 73   from tensorflow.python._pywrap_tensorflow_internal import *
#      74 # This try catch logic is because there is no bazel equivalent for py_extension.
#      75 # Externally in opensource we must enable exceptions to load the shared object
#      76 # by exposing the PyInit symbols with pybind. This error will only be
#      77 # caught internally or if someone changes the name of the target _pywrap_tensorflow_internal.
#      78
#      79 # This logic is used in other internal projects using py_extension.
#
# ImportError: DLL load failed while importing _pywrap_tensorflow_internal: A dynamic link library (DLL) initialization routine failed.
#
# ...

# %%
# TODO: Load MNIST data
# Use mnist.load_data() to get X_train, y_train, X_test, y_test

# YOUR CODE HERE

# %%
# TODO: Normalize and reshape
# 1) Scale pixels to 0-1
# 2) Reshape to (28, 28, 1) for CNN input

# YOUR CODE HERE

# %%
# TODO: Visualize a few samples
# Display 5 images with labels

# YOUR CODE HERE

# %%
# TODO: Build the CNN model
# Suggested layers: Conv2D -> MaxPooling -> Conv2D -> MaxPooling -> Flatten -> Dense -> Dense
# Use relu for hidden layers and softmax for output

# YOUR CODE HERE

# %%
# TODO: Compile and train
# Loss: sparse_categorical_crossentropy | Optimizer: adam | Metric: accuracy
# Train for ~5 epochs, batch_size=64, validation_split=0.1

# YOUR CODE HERE

# %%
# TODO: Evaluate the model
# Print test accuracy

# YOUR CODE HERE

# %%
# TODO: Predict and visualize
# Show 5 test images with predicted + true labels

# YOUR CODE HERE

# %% [markdown]
# ## ✍️ Reflection (include in your submission)
# - Describe your CNN architecture (layers, filters, activations).
# - What accuracy did you achieve?
# - Show one mistake and explain why the model might have struggled.
