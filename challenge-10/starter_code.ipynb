# %% [markdown]
# # Challenge 10: Messy Data Mystery
#
# Mission: Clean a realistic messy dataset and produce a validated analysis-ready file.
#
# Complete each TODO in order.

# %% [markdown]
# ## 1. Setup: Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print('Imports loaded')

# %% [markdown]
# ## 2. Load and inspect raw data
#
# TODO:
# 1. Load `data/messy_cafe_sales.csv`
# 2. Print shape and first rows
# 3. Inspect data types and missing values

# %%
# TODO: load dataframe and inspect
# df = ...
# print(df.head())
# print(df.shape)
# print(df.info())

# %% [markdown]
# ## 3. Build a quick data-quality profile
#
# TODO:
# - Create a table with missing count, missing percent, and unique count for each column
# - Count duplicate rows

# %%
# TODO: quality profile and duplicate count

# %% [markdown]
# ## 4. Parse dates and standardize text fields
#
# TODO:
# - Parse `sale_date` with `errors='coerce'`
# - Standardize `region`, `product_category`, and `payment_type` (trim/lowercase)
# - Map known typos/variants to clean labels

# %%
# TODO: parse dates and clean text columns
# Tip: build small mapping dictionaries

# %% [markdown]
# ## 5. Remove duplicates and convert numeric types
#
# TODO:
# - Drop duplicate rows
# - Convert `units_sold`, `unit_price`, `discount_pct`, `reported_revenue` to numeric
# - Display summary stats

# %%
# TODO: deduplicate + numeric conversion + describe

# %% [markdown]
# ## 6. Handle missing values
#
# TODO:
# - Decide and apply a strategy for missing values
# - For invalid dates (`NaT`), choose a clear action
# - Explain your choices in a comment

# %%
# TODO: missing-value strategy
# Example: median for numeric, mode for category, drop invalid dates

# %% [markdown]
# ## 7. Fix impossible values and recompute revenue
#
# TODO:
# - Remove/fix unrealistic values (negative discounts, extreme prices, etc.)
# - Create `calculated_revenue = units_sold * unit_price * (1 - discount_pct/100)`
# - Compare to `reported_revenue`

# %%
# TODO: enforce realistic ranges and recompute revenue

# %% [markdown]
# ## 8. Detect and treat outliers
#
# TODO:
# - Use an IQR-based approach on key numeric columns
# - Either cap outliers or remove them (choose and justify)
# - Show before/after comparison

# %%
# TODO: outlier handling (IQR)
# Tip: write a helper function

# %% [markdown]
# ## 9. Validation checks
#
# TODO:
# - Build a final quality-check dictionary/table
# - Confirm no duplicates
# - Confirm missing values are handled
# - Confirm no invalid discounts or negative calculated revenue

# %%
# TODO: final validation checks

# %% [markdown]
# ## 10. Save clean dataset
#
# TODO:
# - Save cleaned data to `data/clean_cafe_sales.csv`
# - Print final row count

# %%
# TODO: export clean dataset

# %% [markdown]
# ## 11. One quick visualization
#
# Create one chart that demonstrates impact of cleaning.
#
# Ideas:
# - Distribution of `units_sold` before vs after
# - Top product categories after standardization
# - Revenue by region after cleaning

# %%
# TODO: one chart to show cleaning impact

# %% [markdown]
# ## Analysis Questions
#
# 1. What were the 5 most serious data-quality issues?
# 2. Which cleaning decision was most important for trustworthiness?
# 3. Where could your cleaning strategy introduce bias or distortion?
# 4. How would you automate these checks in a real pipeline?

# %% [markdown]
# ## Bonus (Optional)
#
# Create a reusable function `run_quality_checks(df)` that returns a summary table.
#
# Then run it on raw data and clean data to compare quality improvements.
